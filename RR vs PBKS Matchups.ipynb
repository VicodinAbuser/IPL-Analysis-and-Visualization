# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cufflinks as cf
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
cf.go_offline()
# %matplotlib inline

deliveries = pd.read_csv("IPL Ball-by-Ball 2008-2020.csv")
matches = pd.read_csv("IPL Matches 2008-2020.csv")

deliveries_matches = deliveries.merge(matches, how='left', on='id')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
#Matchups to look forward to
Buttler vs Shami
M Ashwin vs Stokes
M Ashwin vs Samson
Shami vs Samson
Shami vs Stokes
Gopal vs Rahul
Gopal vs Mayank
Gopal vs Gayle
Gopal vs Pooran
Tewatia vs Rahul
Tewatia vs Mayank
Tewatia vs Gayle
Tewatia vs Pooran
Morris vs Rahul
Morris vs Mayank
Morris vs Gayle
Morris vs Pooran
Unadkat vs top 4

# %%
RR_PBKS_Matchups = pd.DataFrame(columns=['Matchup','Balls', 'Runs', 'Wickets', 'Average', 'Strike Rate'])

# %%
shami_vs_buttler = deliveries_matches[deliveries_matches['bowler'].str.endswith('Shami') & deliveries_matches['batsman'].str.endswith('Buttler')]
# Out:
# 25

# %%
shami_vs_samson = deliveries_matches[deliveries_matches['bowler'].str.endswith('Shami') & deliveries_matches['batsman'].str.endswith('Samson')]
shami_vs_samson
# Out:
#              id  inning  over  ball    batsman  non_striker          bowler  \
# 99729    733975       2     4     3  SV Samson      KK Nair  Mohammed Shami
# 99732    733975       2     4     6  SV Samson      KK Nair  Mohammed Shami
# 151651  1136566       1     6     3  SV Samson    AM Rahane  Mohammed Shami
# 165586  1175359       2    15     2  SV Samson    SPD Smith  Mohammed Shami
# 165587  1175359       2    15     3  SV Samson    SPD Smith  Mohammed Shami
# 165589  1175359       2    15     5  SV Samson    SPD Smith  Mohammed Shami
# 172346  1178407       2     8     3  SV Samson  RA Tripathi  Mohammed Shami
# 172347  1178407       2     8     4  SV Samson  RA Tripathi  Mohammed Shami
# 172348  1178407       2     8     5  SV Samson  RA Tripathi  Mohammed Shami
# 187466  1216527       2     3     6  SV Samson    SPD Smith  Mohammed Shami
# 187541  1216527       2    16     1  SV Samson    R Tewatia  Mohammed Shami
#
# ...

# %%
shami_vs_stokes = deliveries_matches[deliveries_matches['bowler'].str.endswith('Shami') & deliveries_matches['batsman'].str.endswith('Stokes')]
shami_vs_stokes
# Out:
#              id  inning  over  ball    batsman non_striker          bowler  \
# 148498  1082642       2    15     2  BA Stokes   MK Tiwary  Mohammed Shami
# 148499  1082642       2    15     3  BA Stokes   MK Tiwary  Mohammed Shami
# 148500  1082642       2    15     4  BA Stokes   MK Tiwary  Mohammed Shami
# 148501  1082642       2    15     5  BA Stokes   MK Tiwary  Mohammed Shami
# 189964  1216537       2     4     2  BA Stokes  RV Uthappa  Mohammed Shami
# 189965  1216537       2     4     3  BA Stokes  RV Uthappa  Mohammed Shami
# 189966  1216537       2     4     4  BA Stokes  RV Uthappa  Mohammed Shami
# 189967  1216537       2     4     5  BA Stokes  RV Uthappa  Mohammed Shami
# 189986  1216537       2     1     2  BA Stokes  RV Uthappa  Mohammed Shami
# 189987  1216537       2     1     3  BA Stokes  RV Uthappa  Mohammed Shami
# 189988  1216537       2     1     4  BA Stokes  RV Uthappa  Mohammed Shami
# ...

# %%
gopal_vs_rahul = deliveries_matches[deliveries_matches['bowler'].str.endswith('Gopal') & deliveries_matches['batsman'].str.endswith('Rahul')]
gopal_vs_rahul
# Out:
#              id  inning  over  ball   batsman non_striker   bowler  \
# 159332  1136598       2     9     2  KL Rahul     KK Nair  S Gopal
# 159334  1136598       2     9     4  KL Rahul     KK Nair  S Gopal
# 159355  1136598       2    13     1  KL Rahul  MP Stoinis  S Gopal
# 159356  1136598       2    13     2  KL Rahul  MP Stoinis  S Gopal
# 159360  1136598       2     7     2  KL Rahul     KK Nair  S Gopal
# 159361  1136598       2     7     3  KL Rahul     KK Nair  S Gopal
# 159364  1136598       2     7     6  KL Rahul     KK Nair  S Gopal
# 172252  1178407       1     7     2  KL Rahul  MA Agarwal  S Gopal
# 172256  1178407       1     7     6  KL Rahul  MA Agarwal  S Gopal
# 172263  1178407       1     9     1  KL Rahul   DA Miller  S Gopal
# 172265  1178407       1     9     3  KL Rahul   DA Miller  S Gopal
# 172267  1178407       1     9     5  KL Rahul   DA Miller  S Gopal
# 172268  1178407       1     9     6  KL Rahul   DA Miller  S Gopal
# ...

# %%
gopal_vs_mayank = deliveries_matches[deliveries_matches['bowler'].str.endswith('Gopal') & deliveries_matches['batsman'].str.endswith('Agarwal')]
gopal_vs_mayank
# Out:
#              id  inning  over  ball     batsman non_striker   bowler  \
# 172251  1178407       1     7     1  MA Agarwal    KL Rahul  S Gopal
# 172253  1178407       1     7     3  MA Agarwal    KL Rahul  S Gopal
# 172254  1178407       1     7     4  MA Agarwal    KL Rahul  S Gopal
# 172255  1178407       1     7     5  MA Agarwal    KL Rahul  S Gopal
# 187406  1216527       1    14     6  MA Agarwal    KL Rahul  S Gopal
# 187416  1216527       1    14     3  MA Agarwal    KL Rahul  S Gopal
# 187432  1216527       1    12     5  MA Agarwal    KL Rahul  S Gopal
# 187433  1216527       1    12     6  MA Agarwal    KL Rahul  S Gopal
# 187595  1216527       1     6     3  MA Agarwal    KL Rahul  S Gopal
# 187597  1216527       1     6     5  MA Agarwal    KL Rahul  S Gopal
# 187606  1216527       1     8     2  MA Agarwal    KL Rahul  S Gopal
# 187607  1216527       1     8     3  MA Agarwal    KL Rahul  S Gopal
# 187608  1216527       1     8     4  MA Agarwal    KL Rahul  S Gopal
# ...

# %%
fizz_vs_gayle = deliveries_matches[deliveries_matches['bowler'].str.endswith('Rahman') & deliveries_matches['batsman'].str.endswith('Pooran')]
fizz_vs_gayle
# Out:
# Empty DataFrame
# Columns: [id, inning, over, ball, batsman, non_striker, bowler, batsman_runs, extra_runs, total_runs, non_boundary, is_wicket, dismissal_kind, player_dismissed, fielder, extras_type, batting_team, bowling_team, city, date, player_of_match, venue, neutral_venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, eliminator, method, umpire1, umpire2]
# Index: []
#
# [0 rows x 34 columns]

# %%
unadkat_vs_gayle.is_wicket.sum()
# Out:
# 0

# %%
RR_PBKS_Matchups = RR_PBKS_Matchups.append(new_row, ignore_index=True)

# %%
new_row = {'Matchup': 'Unadkat vs Gayle' , 'Balls': 28, 'Runs': 72, 'Wickets':0, 'Average': 72, 'Strike Rate': 257.14 }

# %%
RR_PBKS_Matchups = RR_PBKS_Matchups[['Matchup', 'Balls', 'Runs', 'Wickets', 'Average', 'Strike Rate']]
RR_PBKS_Matchups
# Out:
#               Matchup Balls Runs Wickets Average Strike Rate
# 0    Shami vs Buttler    21   25       1      25      119.04
# 1     Shami vs Samson    11   23       1      23      209.09
# 2     Shami vs Stokes    12   16       1      16      133.33
# 3      Gopal vs Rahul    34   34       0      34         100
# 4     Gopal vs Mayank    16   41       0      41      256.25
# 5    Tewatia vs Rahul     7    7       0       7         100
# 6   Tewatia vs Mayank     4   17       0      17         425
# 7    Tewatia vs Gayle    18   18       0      18         100
# 8     Morris vs Rahul    23   41       1      41      178.26
# 9    Morris vs Mayank    23   23       1      23         100
# 10    Morris vs Gayle    46   43       3   14.33       93.47
# 11   Unadkat vs Rahul    43   72       1      72      167.44
# 12  Unadkat vs Mayank    15   25       0      25      166.67
# 13   Unadkat vs Gayle    28   72       0      72      257.14

# %%
RR_PBKS_Matchups.style.set_properties(**{'background-color': '#224488', 'color': 'white',
                           'border-color': 'yellow'})
# Out:
# <style  type="text/css" >
# ...

# %%
RR_PBKS_Matchups_style = RR_PBKS_Matchups.style.set_properties(**{
    'font-size': '14pt',
})

# %%
RR_PBKS_Matchups_style.format({
    'Strike Rate': '{:,.2f}'.format,
})
# Out:
# <style  type="text/css" >
# ...

# %%
RR_PBKS_Matchups['Average'] = [25,23, 16, np.nan, np.nan, np.nan, np.nan, np.nan, 41, 21, 14.33, 72, np.nan, np.nan]

# %%
RR_PBKS_Matchups_style.set_precision(2)
# Out:
# <style  type="text/css" >
# ...

# %%
RR_PBKS_Matchups_style.background_gradient(cmap='rainbow', subset=["Balls", "Runs", "Wickets", "Average", "Strike Rate"])
# Out:
# <style  type="text/css" >
# #T_32ef9_row0_col0{
#             font-size:  14pt;
#             font-size:  14pt;
#             font-size:  14pt;
#             background-color:  #4ef3cd;
#             color:  #000000;
#             font-size:  14pt;
#             background-color:  #4ef3cd;
#             color:  #000000;
#             background-color:  pink;
#             font-size:  14pt;
#             background-color:  #4ef3cd;
#             color:  #000000;
#             background-color:  pink;
#             background-color:  #4ef3cd;
#             color:  #000000;
#             font-size:  14pt;
#             background-color:  #4ef3cd;
#             color:  #000000;
#             background-color:  pink;
#             background-color:  #4ef3cd;
#             color:  #000000;
#             background-color:  #4ef3cd;
#             color:  #000000;
#             font-size:  14pt;
#             background-color:  #4ef3cd;
#             color:  #000000;
# ...

# %%
RR_PBKS_Matchups.set_index('Matchup', inplace=True)

# %%
x = math.inf
print(type(x))
# Out:
# <class 'float'>

# %%
# Out:
# inf
