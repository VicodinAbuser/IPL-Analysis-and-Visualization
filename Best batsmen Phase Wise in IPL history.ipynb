# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cufflinks as cf
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
cf.go_offline()
# %matplotlib inline

deliveries = pd.read_csv("IPL Ball-by-Ball 2008-2020.csv")
matches = pd.read_csv("IPL Matches 2008-2020.csv")

deliveries_matches = deliveries.merge(matches, how='left', on='id')
# deliveries_matches[deliveries_matches['date'].str.startswith('2018') | deliveries_matches['date'].str.startswith('2019') | deliveries_matches['date'].str.startswith('2020')]
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
def powerplay_batting(batsmen_list, batsmen_over_by_over):
    pp_batting = pd.DataFrame(columns=['batsman', 'balls faced', 'runs', 'dismissals', 'average', 'strike rate'])

    for batsman in batsmen_list:
        balls_faced = 0
        runs_scored = 0
        dismissals = 0

        if 0 in batsmen_over_by_over.loc[batsman].index:
            balls_faced += batsmen_over_by_over.loc[(batsman, 0)]['ball']
            runs_scored += batsmen_over_by_over.loc[(batsman, 0)]['batsman_runs']
            dismissals += batsmen_over_by_over.loc[(batsman, 0)]['is_wicket']
        if 1 in batsmen_over_by_over.loc[batsman].index:
            balls_faced += batsmen_over_by_over.loc[(batsman, 1)]['ball']
            runs_scored += batsmen_over_by_over.loc[(batsman, 1)]['batsman_runs']
            dismissals += batsmen_over_by_over.loc[(batsman, 1)]['is_wicket']
        if 2 in batsmen_over_by_over.loc[batsman].index:
            balls_faced += batsmen_over_by_over.loc[(batsman, 2)]['ball']
            runs_scored += batsmen_over_by_over.loc[(batsman, 2)]['batsman_runs']
            dismissals += batsmen_over_by_over.loc[(batsman, 2)]['is_wicket']
        if 3 in batsmen_over_by_over.loc[batsman].index:
            balls_faced += batsmen_over_by_over.loc[(batsman, 3)]['ball']
            runs_scored += batsmen_over_by_over.loc[(batsman, 3)]['batsman_runs']
            dismissals += batsmen_over_by_over.loc[(batsman, 3)]['is_wicket']
        if 4 in batsmen_over_by_over.loc[batsman].index:
            balls_faced += batsmen_over_by_over.loc[(batsman, 4)]['ball']
            runs_scored += batsmen_over_by_over.loc[(batsman, 4)]['batsman_runs']
            dismissals += batsmen_over_by_over.loc[(batsman, 4)]['is_wicket']
            
        if 5 in batsmen_over_by_over.loc[batsman].index:
            balls_faced += batsmen_over_by_over.loc[(batsman, 5)]['ball']
            runs_scored += batsmen_over_by_over.loc[(batsman, 5)]['batsman_runs']
            dismissals += batsmen_over_by_over.loc[(batsman, 5)]['is_wicket']
        
            
        if(balls_faced > 0):
            if(dismissals > 0):
                average = runs_scored/dismissals
            else:
                average = runs_scored
            strike_rate = runs_scored/balls_faced*100
            pp_batting = pp_batting.append({'batsman':batsman, 'balls faced': balls_faced, 'runs': runs_scored, 'dismissals': dismissals, 'average':average, 'strike rate': strike_rate}, ignore_index=True)

    pp_batting = pp_batting.round(decimals=2)
    return pp_batting

# %%
def middle_overs_batting(batsmen_list, batsmen_over_by_over):
    mo_batting = pd.DataFrame(columns=['batsman', 'balls faced', 'runs', 'dismissals', 'average', 'strike rate'])

    for batsman in batsmen_list:
        balls_faced = 0
        runs_scored = 0
        dismissals = 0

        if 6 in batsmen_over_by_over.loc[batsman].index:
            balls_faced += batsmen_over_by_over.loc[(batsman, 6)]['ball']
            runs_scored += batsmen_over_by_over.loc[(batsman, 6)]['batsman_runs']
            dismissals += batsmen_over_by_over.loc[(batsman, 6)]['is_wicket']
        if 7 in batsmen_over_by_over.loc[batsman].index:
            balls_faced += batsmen_over_by_over.loc[(batsman, 7)]['ball']
            runs_scored += batsmen_over_by_over.loc[(batsman, 7)]['batsman_runs']
            dismissals += batsmen_over_by_over.loc[(batsman, 7)]['is_wicket']
        if 8 in batsmen_over_by_over.loc[batsman].index:
            balls_faced += batsmen_over_by_over.loc[(batsman, 8)]['ball']
            runs_scored += batsmen_over_by_over.loc[(batsman, 8)]['batsman_runs']
            dismissals += batsmen_over_by_over.loc[(batsman, 8)]['is_wicket']
        if 9 in batsmen_over_by_over.loc[batsman].index:
            balls_faced += batsmen_over_by_over.loc[(batsman, 9)]['ball']
            runs_scored += batsmen_over_by_over.loc[(batsman, 9)]['batsman_runs']
            dismissals += batsmen_over_by_over.loc[(batsman, 9)]['is_wicket']
        if 10 in batsmen_over_by_over.loc[batsman].index:
            balls_faced += batsmen_over_by_over.loc[(batsman, 10)]['ball']
            runs_scored += batsmen_over_by_over.loc[(batsman, 10)]['batsman_runs']
            dismissals += batsmen_over_by_over.loc[(batsman, 10)]['is_wicket']
            
        if 11 in batsmen_over_by_over.loc[batsman].index:
            balls_faced += batsmen_over_by_over.loc[(batsman, 11)]['ball']
            runs_scored += batsmen_over_by_over.loc[(batsman, 11)]['batsman_runs']
            dismissals += batsmen_over_by_over.loc[(batsman, 11)]['is_wicket']
        if 12 in batsmen_over_by_over.loc[batsman].index:
            balls_faced += batsmen_over_by_over.loc[(batsman, 12)]['ball']
            runs_scored += batsmen_over_by_over.loc[(batsman, 12)]['batsman_runs']
            dismissals += batsmen_over_by_over.loc[(batsman, 12)]['is_wicket']
        if 13 in batsmen_over_by_over.loc[batsman].index:
            balls_faced += batsmen_over_by_over.loc[(batsman, 13)]['ball']
            runs_scored += batsmen_over_by_over.loc[(batsman, 13)]['batsman_runs']
            dismissals += batsmen_over_by_over.loc[(batsman, 13)]['is_wicket']
        if 14 in batsmen_over_by_over.loc[batsman].index:
            balls_faced += batsmen_over_by_over.loc[(batsman, 14)]['ball']
            runs_scored += batsmen_over_by_over.loc[(batsman, 14)]['batsman_runs']
            dismissals += batsmen_over_by_over.loc[(batsman, 14)]['is_wicket']
        if 15 in batsmen_over_by_over.loc[batsman].index:
            balls_faced += batsmen_over_by_over.loc[(batsman, 15)]['ball']
            runs_scored += batsmen_over_by_over.loc[(batsman, 15)]['batsman_runs']
            dismissals += batsmen_over_by_over.loc[(batsman, 15)]['is_wicket']
            
        if(balls_faced > 0):
            if(dismissals > 0):
                average = runs_scored/dismissals
            else:
                average = runs_scored
            strike_rate = runs_scored/balls_faced*100
            mo_batting = mo_batting.append({'batsman':batsman, 'balls faced': balls_faced, 'runs': runs_scored, 'dismissals': dismissals, 'average':average, 'strike rate': strike_rate}, ignore_index=True)

    mo_batting = mo_batting.round(decimals=2)
    return mo_batting

# %%
def death_batting(batsmen_list, batsmen_over_by_over):
    death_batting = pd.DataFrame(columns=['batsman', 'balls faced', 'runs', 'dismissals', 'average', 'strike rate'])

    for batsman in batsmen_list:
        balls_faced = 0
        runs_scored = 0
        dismissals = 0

        if 16 in batsmen_over_by_over.loc[batsman].index:
            balls_faced += batsmen_over_by_over.loc[(batsman, 16)]['ball']
            runs_scored += batsmen_over_by_over.loc[(batsman, 16)]['batsman_runs']
            dismissals += batsmen_over_by_over.loc[(batsman, 16)]['is_wicket']
        if 17 in batsmen_over_by_over.loc[batsman].index:
            balls_faced += batsmen_over_by_over.loc[(batsman, 17)]['ball']
            runs_scored += batsmen_over_by_over.loc[(batsman, 17)]['batsman_runs']
            dismissals += batsmen_over_by_over.loc[(batsman, 17)]['is_wicket']
        if 18 in batsmen_over_by_over.loc[batsman].index:
            balls_faced += batsmen_over_by_over.loc[(batsman, 18)]['ball']
            runs_scored += batsmen_over_by_over.loc[(batsman, 18)]['batsman_runs']
            dismissals += batsmen_over_by_over.loc[(batsman, 18)]['is_wicket']
        if 19 in batsmen_over_by_over.loc[batsman].index:
            balls_faced += batsmen_over_by_over.loc[(batsman, 19)]['ball']
            runs_scored += batsmen_over_by_over.loc[(batsman, 19)]['batsman_runs']
            dismissals += batsmen_over_by_over.loc[(batsman, 19)]['is_wicket']        
            
        if(balls_faced > 0):
            if(dismissals > 0):
                average = runs_scored/dismissals
            else:
                average = runs_scored
            strike_rate = runs_scored/balls_faced*100
            death_batting = death_batting.append({'batsman':batsman, 'balls faced': balls_faced, 'runs': runs_scored, 'dismissals': dismissals, 'average':average, 'strike rate': strike_rate}, ignore_index=True)

    death_batting = death_batting.round(decimals=2)
    return death_batting

# %%
deliveries_matches.ball=1
batsmen_over_by_over = deliveries_matches.groupby(by=['batsman', 'over']).sum()
batsmen_over_by_over
# Out:
#                            id  inning  ball  batsman_runs  extra_runs  \
# batsman        over
# A Ashish Reddy 4      1196088       4     2             0           0
#                5      2990220      10     5             5           1
#                11      980907       2     1             1           0
#                12     8223795      14     9             9           0
#                13    11946432      21    15            22           0
# ...                       ...     ...   ...           ...         ...
# Z Khan         15     6024523      19    11             7           0
#                16     9300889      23    16             5           0
#                17    10232635      27    18            15           0
#                18    14285872      47    30            41           1
#                19    17363459      48    34            40           3
#
#                      total_runs  non_boundary  is_wicket  neutral_venue  \
# batsman        over
# ...

# %%
batsmen_over_by_over.index.get_level_values(0).value_counts().index
# Out:
# Index(['MC Henriques', 'HH Pandya', 'DB Ravi Teja', 'Mandeep Singh',
#        'DJ Bravo', 'MV Boucher', 'GH Vihari', 'GC Smith', 'MP Stoinis',
#        'AM Rahane',
#        ...
#        'B Stanlake', 'YA Abdulla', 'RR Bhatkal', 'CRD Fernando',
#        'PM Sarvesh Kumar', 'U Kaul', 'S Kaushik', 'S Lamichhane',
#        'P Parameswaran', 'JE Taylor'],
#       dtype='object', length=537)

# %%
middle_overs_batsmen = middle_overs_batting(batsmen_over_by_over.index.get_level_values(0).value_counts().index, batsmen_over_by_over)
middle_overs_batsmen
# Out:
#            batsman  balls faced   runs  dismissals  average  strike rate
# 0     MC Henriques        467.0  530.0        22.0    24.09       113.49
# 1        HH Pandya        389.0  493.0        15.0    32.87       126.74
# 2     DB Ravi Teja        174.0  200.0         5.0    40.00       114.94
# 3    Mandeep Singh        632.0  737.0        31.0    23.77       116.61
# 4         DJ Bravo        670.0  625.0        28.0    22.32        93.28
# ..             ...          ...    ...         ...      ...          ...
# 430    Kamran Khan          5.0    3.0         1.0     3.00        60.00
# 431     GD McGrath          3.0    4.0         0.0     4.00       133.33
# 432    SS Cottrell          1.0    0.0         0.0     0.00         0.00
# 433    Sunny Gupta          1.0    0.0         1.0     0.00         0.00
# 434        DR Sams          2.0    0.0         1.0     0.00         0.00
#
# [435 rows x 6 columns]

# %%
middle_overs_batsmen_min250_runs = middle_overs_batsmen[middle_overs_batsmen['runs'] > 249]

# %%
middle_overs_batsmen_min250_runs
# Out:
#            batsman  balls faced   runs  dismissals  average  strike rate
# 0     MC Henriques        467.0  530.0        22.0    24.09       113.49
# 1        HH Pandya        389.0  493.0        15.0    32.87       126.74
# 3    Mandeep Singh        632.0  737.0        31.0    23.77       116.61
# 4         DJ Bravo        670.0  625.0        28.0    22.32        93.28
# 7         GC Smith        266.0  329.0        13.0    25.31       123.68
# ..             ...          ...    ...         ...      ...          ...
# 169     AL Menaria        294.0  314.0        14.0    22.43       106.80
# 172     AD Mathews        359.0  392.0        11.0    35.64       109.19
# 175      STR Binny        461.0  526.0        27.0    19.48       114.10
# 185       AR Patel        437.0  476.0        18.0    26.44       108.92
# 203  ST Jayasuriya        170.0  254.0         9.0    28.22       149.41
#
# [103 rows x 6 columns]

# %%
middle_overs_batsmen_min250_runs.sort_values('runs', ascending=False, inplace=True)

# %%
middle_overs_batsmen_min250_runs.head(25)
# Out:
#             batsman  balls faced    runs  dismissals  average  strike rate
# 77         SK Raina       2469.0  3201.0        94.0    34.05       129.65
# 40          V Kohli       2576.0  3186.0        79.0    40.33       123.68
# 96        RG Sharma       2462.0  2945.0        87.0    33.85       119.62
# 80   AB de Villiers       2097.0  2879.0        61.0    47.20       137.29
# 46       KD Karthik       2089.0  2506.0        95.0    26.38       119.96
# 88       RV Uthappa       1883.0  2367.0        88.0    26.90       125.70
# 52        DA Warner       1683.0  2312.0        58.0    39.86       137.37
# 117        MS Dhoni       2152.0  2279.0        52.0    43.83       105.90
# 29        AT Rayudu       1840.0  2212.0        68.0    32.53       120.22
# 65         S Dhawan       1758.0  2168.0        67.0    32.36       123.32
# 51        SR Watson       1437.0  2164.0        68.0    31.82       150.59
# ...

# %%
top25_mid_overs_batters = middle_overs_batsmen_min250_runs.head(25)

# %%
plt.figure(figsize=(18,8))
sns.set(font_scale=1.4)
# sns.set_style('darkgrid')
graph = sns.barplot(x='batsman', y='runs', data=middle_overs_batsmen_min250_runs.head(25))
# plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0., title='Average', shadow=True)
plt.title("Most runs(top 25) in the middle overs(7-16) in IPL history")
plt.xticks(rotation=80);

# for line in range(0,middle_overs_batsmen_min250_runs.head(25).shape[0]):
#      plt.text(middle_overs_batsmen_min250_runs.head(25)['batsman'][line], middle_overs_batsmen_min250_runs.head(25)['runs'][line]+1.3, middle_overs_batsmen_min250_runs.head(25)['runs'][line], horizontalalignment='left', size='small', color='black', )
for p in graph.patches:
        graph.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.4, p.get_height()),
                    ha='center', va='bottom',
                    color= 'black', fontsize=13)

# %%
plt.figure(figsize=(18,8))
sns.set(font_scale=1.4)
# sns.set_style('darkgrid')
graph = sns.barplot(x='batsman', y='average', data=top25_mid_overs_batters.sort_values('average', ascending=False).head(25))
# plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0., title='Average', shadow=True)
plt.title("Highest Average(among top 25 run getters) in the middle overs(7-16) in IPL history")
plt.xticks(rotation=80);

for p in graph.patches:
        graph.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.4, p.get_height()),
                    ha='center', va='bottom',
                    color= 'black', fontsize=13)

# %%
plt.figure(figsize=(18,8))
sns.set(font_scale=1.4)
# sns.set_style('darkgrid')
graph = sns.barplot(x='batsman', y='strike rate', data=top25_mid_overs_batters.sort_values('strike rate', ascending=False).head(25))
# plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0., title='Average', shadow=True)
plt.title("Highest Strike Rate(among top 25 run getters) in the middle overs(7-16) in IPL history")
plt.xticks(rotation=80);

for p in graph.patches:
        graph.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.4, p.get_height()),
                    ha='center', va='bottom',
                    color= 'black', fontsize=13)

# %%
top25_mid_overs_batters.sort_values('strike rate', ascending=False).head(25)
# Out:
#             batsman  balls faced    runs  dismissals  average  strike rate
# 36         CH Gayle       1362.0  2082.0        43.0    48.42       152.86
# 51        SR Watson       1437.0  2164.0        68.0    31.82       150.59
# 62         SE Marsh       1050.0  1540.0        35.0    44.00       146.67
# 30          RR Pant       1008.0  1437.0        34.0    42.26       142.56
# 52        DA Warner       1683.0  2312.0        58.0    39.86       137.37
# 80   AB de Villiers       2097.0  2879.0        61.0    47.20       137.29
# 85        SV Samson       1122.0  1497.0        45.0    33.27       133.42
# 16        YK Pathan       1541.0  2003.0        65.0    30.82       129.98
# 77         SK Raina       2469.0  3201.0        94.0    34.05       129.65
# 103         SS Iyer       1035.0  1307.0        44.0    29.70       126.28
# 88       RV Uthappa       1883.0  2367.0        88.0    26.90       125.70
# ...

# %%
middle_overs_batsmen_min250_runs[middle_overs_batsmen_min250_runs['batsman'].str.endswith('Sehwag')]
# Out:
#       batsman  balls faced    runs  dismissals  average  strike rate
# 129  V Sehwag        658.0  1102.0        35.0    31.49       167.48

# %%
top25_mid_overs_batters
# Out:
#             batsman  balls faced    runs  dismissals  average  strike rate
# 77         SK Raina       2469.0  3201.0        94.0    34.05       129.65
# 40          V Kohli       2576.0  3186.0        79.0    40.33       123.68
# 96        RG Sharma       2462.0  2945.0        87.0    33.85       119.62
# 80   AB de Villiers       2097.0  2879.0        61.0    47.20       137.29
# 46       KD Karthik       2089.0  2506.0        95.0    26.38       119.96
# 88       RV Uthappa       1883.0  2367.0        88.0    26.90       125.70
# 52        DA Warner       1683.0  2312.0        58.0    39.86       137.37
# 117        MS Dhoni       2152.0  2279.0        52.0    43.83       105.90
# 29        AT Rayudu       1840.0  2212.0        68.0    32.53       120.22
# 65         S Dhawan       1758.0  2168.0        67.0    32.36       123.32
# 51        SR Watson       1437.0  2164.0        68.0    31.82       150.59
# ...

# %%
middle_overs_batsmen_min250_runs.head(30)
# Out:
#             batsman  balls faced    runs  dismissals  average  strike rate
# 77         SK Raina       2469.0  3201.0        94.0    34.05       129.65
# 40          V Kohli       2576.0  3186.0        79.0    40.33       123.68
# 96        RG Sharma       2462.0  2945.0        87.0    33.85       119.62
# 80   AB de Villiers       2097.0  2879.0        61.0    47.20       137.29
# 46       KD Karthik       2089.0  2506.0        95.0    26.38       119.96
# 88       RV Uthappa       1883.0  2367.0        88.0    26.90       125.70
# 52        DA Warner       1683.0  2312.0        58.0    39.86       137.37
# 117        MS Dhoni       2152.0  2279.0        52.0    43.83       105.90
# 29        AT Rayudu       1840.0  2212.0        68.0    32.53       120.22
# 65         S Dhawan       1758.0  2168.0        67.0    32.36       123.32
# 51        SR Watson       1437.0  2164.0        68.0    31.82       150.59
# ...

# %%
middle_overs_batsmen_min_100_balls = middle_overs_batsmen[middle_overs_batsmen['balls faced'] > 99]

# %%
middle_overs_batsmen_min_100_balls.sort_values('strike rate', ascending=False, inplace=True)
middle_overs_batsmen_min_100_balls
# Out:
#         batsman  balls faced    runs  dismissals  average  strike rate
# 56       MM Ali        135.0   233.0         8.0    29.12       172.59
# 168    N Pooran        227.0   385.0         8.0    48.12       169.60
# 129    V Sehwag        658.0  1102.0        35.0    31.49       167.48
# 27   GJ Maxwell        705.0  1088.0        45.0    24.18       154.33
# 157  AD Russell        542.0   829.0        23.0    36.04       152.95
# ..          ...          ...     ...         ...      ...          ...
# 107   R McLaren        109.0    92.0         3.0    30.67        84.40
# 191     Y Nagar        159.0   134.0         3.0    44.67        84.28
# 212    R Bhatia        139.0   113.0         8.0    14.12        81.29
# 243    SK Warne        103.0    82.0         7.0    11.71        79.61
# 178    A Mishra        196.0   137.0        10.0    13.70        69.90
#
# [158 rows x 6 columns]

# %%
plt.figure(figsize=(18,8))
sns.set(font_scale=1.4)
# sns.set_style('darkgrid')
graph = sns.barplot(x='batsman', y='strike rate', data=middle_overs_batsmen_min_100_balls.head(30))
# plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0., title='Average', shadow=True)
plt.title("Highest Strike Rate(min 100 balls faced) in the middle overs(7-16) in IPL history")
plt.xticks(rotation=80);

for p in graph.patches:
        graph.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.4, p.get_height()),
                    ha='center', va='bottom',
                    color= 'black', fontsize=13)

# %% [markdown]
# ## Best Powerplay Batsmen in IPL History

# %%
powerplay_batsmen = powerplay_batting(batsmen_over_by_over.index.get_level_values(0).value_counts().index, batsmen_over_by_over)
powerplay_batsmen

powerplay_batsmen_min250_runs = powerplay_batsmen[powerplay_batsmen['runs'] > 249]
powerplay_batsmen_min250_runs = powerplay_batsmen_min250_runs.sort_values('runs', ascending=False)
powerplay_batsmen_min_250_balls = powerplay_batsmen[powerplay_batsmen['balls faced'] > 249].sort_values('strike rate', ascending=False)

top25_powerplay_run_scorers = powerplay_batsmen_min250_runs.head(25)
top25_powerplay_avg = powerplay_batsmen_min250_runs.sort_values('average', ascending=False).head(25)
top25_powerplay_strike_rate = powerplay_batsmen_min_250_balls.head(25)

# %% [markdown]
# ## Most runs in PP in IPL History

# %%
plt.figure(figsize=(18,8))
sns.set(font_scale=1.4)
# sns.set_style('darkgrid')
graph = sns.barplot(x='batsman', y='runs', data=top25_powerplay_run_scorers)
# plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0., title='Average', shadow=True)
plt.title("Most runs(top 25) in the Powerplay in IPL history")
plt.xticks(rotation=80);

# for line in range(0,powerplay_batsmen_min250_runs.head(25).shape[0]):
#      plt.text(powerplay_batsmen_min250_runs.head(25)['batsman'][line], powerplay_batsmen_min250_runs.head(25)['runs'][line]+1.3, powerplay_batsmen_min250_runs.head(25)['runs'][line], horizontalalignment='left', size='small', color='black', )
for p in graph.patches:
        graph.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.4, p.get_height()),
                    ha='center', va='bottom',
                    color= 'black', fontsize=13)

# %% [markdown]
# ## Highest Avg in PP History

# %%
plt.figure(figsize=(18,8))
sns.set(font_scale=1.4)
# sns.set_style('darkgrid')
graph = sns.barplot(x='batsman', y='average', data=top25_powerplay_avg)
# plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0., title='Average', shadow=True)
plt.title("Highest Average(min 250 runs) in the Powerplay in IPL history")
plt.xticks(rotation=80);

for p in graph.patches:
        graph.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.4, p.get_height()),
                    ha='center', va='bottom',
                    color= 'black', fontsize=13)

# %% [markdown]
# ## Highest Strike Rate in Powerplay in IPL History

# %%
plt.figure(figsize=(18,8))
sns.set(font_scale=1.4)
# sns.set_style('darkgrid')
graph = sns.barplot(x='batsman', y='strike rate', data=top25_powerplay_strike_rate)
# plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0., title='Average', shadow=True)
plt.title("Highest Strike Rate(min 250 balls) in the Powerplay in IPL history")
plt.xticks(rotation=80);

for p in graph.patches:
        graph.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.4, p.get_height()),
                    ha='center', va='bottom',
                    color= 'black', fontsize=13)

# %% [markdown]
# ## Best Death Overs Batsmen in IPL History

# %%
death_batsmen = death_batting(batsmen_over_by_over.index.get_level_values(0).value_counts().index, batsmen_over_by_over)
death_batsmen

death_batsmen_min250_runs = death_batsmen[death_batsmen['runs'] > 249]
death_batsmen_min250_runs = death_batsmen_min250_runs.sort_values('runs', ascending=False)
death_batsmen_min_250_balls = death_batsmen[death_batsmen['balls faced'] > 249].sort_values('strike rate', ascending=False)

top25_death_run_scorers = death_batsmen_min250_runs.head(25)
top25_death_avg = death_batsmen_min250_runs.sort_values('average', ascending=False).head(25)
top25_death_strike_rate = death_batsmen_min_250_balls.head(25)

# %% [markdown]
# ## Most runs at the death in IPL History

# %%
plt.figure(figsize=(18,8))
sns.set(font_scale=1.4)
# sns.set_style('darkgrid')
graph = sns.barplot(x='batsman', y='runs', data=top25_death_run_scorers)
# plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0., title='Average', shadow=True)
plt.title("Most runs(top 25) at the Death in IPL history")
plt.xticks(rotation=80);

# for line in range(0,powerplay_batsmen_min250_runs.head(25).shape[0]):
#      plt.text(powerplay_batsmen_min250_runs.head(25)['batsman'][line], powerplay_batsmen_min250_runs.head(25)['runs'][line]+1.3, powerplay_batsmen_min250_runs.head(25)['runs'][line], horizontalalignment='left', size='small', color='black', )
for p in graph.patches:
        graph.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.4, p.get_height()),
                    ha='center', va='bottom',
                    color= 'black', fontsize=13)

# %% [markdown]
# ## Highest Avg at the Death in IPL History

# %%
plt.figure(figsize=(18,8))
sns.set(font_scale=1.4)
# sns.set_style('darkgrid')
graph = sns.barplot(x='batsman', y='average', data=top25_death_avg)
# plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0., title='Average', shadow=True)
plt.title("Highest Average(min 250 runs) at the Death in IPL history")
plt.xticks(rotation=80);

for p in graph.patches:
        graph.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.4, p.get_height()),
                    ha='center', va='bottom',
                    color= 'black', fontsize=13)

# %% [markdown]
# ## Highest Strike Rate at the Death in IPL History

# %%
plt.figure(figsize=(18,8))
sns.set(font_scale=1.4)
# sns.set_style('darkgrid')
graph = sns.barplot(x='batsman', y='strike rate', data=top25_death_strike_rate)
# plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0., title='Average', shadow=True)
plt.title("Highest Strike Rate(min 250 balls) at the Death in IPL history")
plt.xticks(rotation=80);

for p in graph.patches:
        graph.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.4, p.get_height()),
                    ha='center', va='bottom',
                    color= 'black', fontsize=13)

# %%
powerplay_batsmen_min250_runs
# Out:
#            batsman  balls faced    runs  dismissals  average  strike rate
# 65        S Dhawan       2204.0  2639.0        74.0    35.66       119.74
# 52       DA Warner       1942.0  2572.0        55.0    46.76       132.44
# 36        CH Gayle       1780.0  2305.0        62.0    37.18       129.49
# 101      G Gambhir       1945.0  2277.0        67.0    33.99       117.07
# 9        AM Rahane       1730.0  1949.0        61.0    31.95       112.66
# ..             ...          ...     ...         ...      ...          ...
# 200    SA Asnodkar        216.0   278.0        10.0    27.80       128.70
# 45   KS Williamson        258.0   276.0         6.0    46.00       106.98
# 161        E Lewis        205.0   275.0         7.0    39.29       134.15
# 142     D Padikkal        219.0   271.0         5.0    54.20       123.74
# 55         HM Amla        206.0   261.0         6.0    43.50       126.70
#
# [68 rows x 6 columns]
